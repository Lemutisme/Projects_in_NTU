# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/Users/clause/Desktop/ZD/St/germancredit.csv')

# %%
df
# Out:
#      Default checkingstatus1  duration history purpose  amount savings employ  \
# 0          0             A11         6     A34     A43    1169     A65    A75
# 1          1             A12        48     A32     A43    5951     A61    A73
# 2          0             A14        12     A34     A46    2096     A61    A74
# 3          0             A11        42     A32     A42    7882     A61    A74
# 4          1             A11        24     A33     A40    4870     A61    A73
# ..       ...             ...       ...     ...     ...     ...     ...    ...
# 995        0             A14        12     A32     A42    1736     A61    A74
# 996        0             A11        30     A32     A41    3857     A61    A73
# 997        0             A14        12     A32     A43     804     A61    A75
# 998        1             A11        45     A32     A43    1845     A61    A73
# 999        0             A12        45     A34     A41    4576     A62    A71
#
# ...

# %%
for i in range(1,22):
    if type(df.iloc[:,i]) == str:
        for j in range(1000):
            df.iloc[j,i] = int(df.iloc[j,i][-1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/fb/8h60y6l97p75gc1bc8g5y9v40000gn/T/ipykernel_85059/3369145081.py in <module>
#       1 for i in range(1,22):
# ----> 2     if type(df.iloc[:,i]) == str:
#       3         for j in range(1000):
#       4             df.iloc[j,i] = int(df.iloc[j,i][-1])
#
# ~/Anaconda/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~/Anaconda/anaconda3/envs/ML/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
# ...
